# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
from sim_class import Simulation

# Class for a PID controller with proportional, integral, and derivative gains
class PIDController:
    def __init__(self, Kp, Ki, Kd, setpoint=0):
        """
        Initializes a PID controller.
        :param Kp: Proportional gain.
        :param Ki: Integral gain.
        :param Kd: Derivative gain.
        :param setpoint: Target value for the controller to achieve.
        """
        self.Kp = Kp
        self.Ki = Ki
        self.Kd = Kd
        self.setpoint = setpoint
        self.integral = 0
        self.previous_error = 0

    # Updates the control signal based on the current value
    def update(self, current_value):
        """
        Calculates the control signal based on the current value.
        :param current_value: Current state variable value.
        :return: Control signal to adjust the variable towards the setpoint.
        """
        error = self.setpoint - current_value
        self.integral += error
        derivative = error - self.previous_error
        self.previous_error = error
        
        # PID control formula
        return self.Kp * error + self.Ki * self.integral + self.Kd * derivative

# Custom Gym environment for controlling a robotic pipette
class OT2Env(gym.Env):
    def __init__(self, render=False, max_steps=10000):
        """
        Custom Gym environment for controlling a robotic pipette using PID controllers.
        :param render: Boolean flag to enable/disable rendering.
        :param max_steps: Maximum number of steps per episode.
        """
        super(OT2Env, self).__init__()
        self.render_enabled = render
        self.max_steps = max_steps

        # Initialize the simulation environment
        self.sim = Simulation(num_agents=1, render=self.render_enabled)

        # Define action and observation spaces
        self.action_space = spaces.Box(
            low=np.array([-1, -1, -1, 0]),
            high=np.array([1, 1, 1, 1]),
            shape=(4,),
            dtype=np.float32
        )
        self.observation_space = spaces.Box(
            low=-np.inf,
            high=np.inf,
            shape=(6,),
            dtype=np.float32
        )

        # Initialize PID controllers for X, Y, and Z axes
        self.pid_x = PIDController(Kp=1.0, Ki=0.1, Kd=0.01)
        self.pid_y = PIDController(Kp=1.0, Ki=0.1, Kd=0.01)
        self.pid_z = PIDController(Kp=1.0, Ki=0.1, Kd=0.01)

        # Track the number of steps and goal position
        self.steps = 0
        self.goal_position = None

    # Resets the environment to its initial state
    def reset(self, seed=None):
        """
        Resets the environment to its initial state.
        :param seed: Random seed for reproducibility.
        :return: Initial observation and metadata.
        """
        if seed is not None:
            np.random.seed(seed)

        # Set a random goal position
        self.goal_position = np.array([
            np.random.uniform(-0.18700, 0.25300),
            np.random.uniform(-0.17050, 0.21950),
            np.random.uniform(0.16940, 0.28950)
        ], dtype=np.float32)

        # Update PID controller setpoints
        self.pid_x.setpoint = self.goal_position[0]
        self.pid_y.setpoint = self.goal_position[1]
        self.pid_z.setpoint = self.goal_position[2]

        # Reset the simulation environment
        observation = self.sim.reset(num_agents=1)

        # Combine current pipette position with the goal position
        pipette_position = np.array(
            observation[f'robotId_{self.sim.robotIds[0]}']['pipette_position'],
            dtype=np.float32
        )
        observation = np.concatenate([pipette_position, self.goal_position], axis=0)

        self.steps = 0
        return observation, {}

    # Executes one step in the environment
    def step(self, action):
        """
        Executes one step in the environment.
        :param action: Action to be executed.
        :return: Tuple (observation, reward, terminated, truncated, info).
        """
        # Run the action in the simulation
        observation = self.sim.run([action])
        pipette_position = np.array(
            observation[f'robotId_{self.sim.robotIds[0]}']['pipette_position'],
            dtype=np.float32
        )

        # Compute control signals using PID controllers
        control_signal_x = self.pid_x.update(pipette_position[0])
        control_signal_y = self.pid_y.update(pipette_position[1])
        control_signal_z = self.pid_z.update(pipette_position[2])

        # Construct the control action
        control_action = np.array([
            control_signal_x,
            control_signal_y,
            control_signal_z,
            0.0
        ], dtype=np.float32)

        # Execute control action in the simulation
        self.sim.run([control_action])

        # Combine current position with goal position for the observation
        observation = np.concatenate([pipette_position, self.goal_position], axis=0)

        # Calculate reward as negative distance to the goal
        distance = np.linalg.norm(pipette_position - self.goal_position)
        reward = -distance

        # Check if the goal is reached (10 mm accuracy)
        terminated = distance <= 0.001  # 1 mm threshold
        if terminated:
            reward = 100  # Reward bonus for achieving the goal

        # Check if maximum steps have been reached
        truncated = self.steps >= self.max_steps

        # Print debug information
        distance_mm = distance * 1000  # Convert distance to mm
        print(f"Step {self.steps}:")
        print(f"  Current Position: {pipette_position}")
        print(f"  Goal Position: {self.goal_position}")
        print(f"  Distance to Goal: {distance_mm:.2f} mm")

        self.steps += 1
        return observation, reward, terminated, truncated, {}

    # Renders the environment
    def render(self):
        """
        Renders the environment.
        """
        if self.render_enabled:
            self.sim.render()

    # Closes the environment and releases resources
    def close(self):
        """
        Closes the environment and releases resources.
        """
        self.sim.close()

# Main entry point for testing the environment
if __name__ == "__main__":
    # Example usage of the environment
    env = OT2Env(render=True)
    observation, _ = env.reset()

    print(f"Goal Position: {env.goal_position}")

    for _ in range(10000):
        action = env.action_space.sample()  # Sample a random action
        observation, reward, terminated, truncated, _ = env.step(action)

        if terminated or truncated:
            print("Goal Reached!" if terminated else "Simulation Truncated.")
            break

    env.close()
# Out:
# pybullet build time: Jan 20 2025 10:18:19
# 2025-01-23 17:33:43.524 Python[51576:2327191] WARNING: Secure coding is not enabled for restorable state! Enable secure coding by implementing NSApplicationDelegate.applicationSupportsSecureRestorableState: and returning YES.
# Version = 4.1 Metal - 86
# Vendor = Apple
# Renderer = Apple M1
# b3Printf: Selected demo: Physics Server
# startThreads creating 1 threads.
# starting thread 0
# started thread 0
# MotionThreadFunc thread started
# Goal Position: [-0.18003549  0.05123494  0.18420415]
# Step 0:
#   Current Position: [0.0735 0.0889 0.1195]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 264.36 mm
# Step 1:
#   Current Position: [0.0739 0.088  0.1211]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 264.23 mm
# Step 2:
#   Current Position: [0.0743 0.0871 0.1223]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 264.21 mm
# Step 3:
#   Current Position: [0.0747 0.0873 0.1239]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 264.25 mm
# Step 4:
#   Current Position: [0.0741 0.0863 0.1249]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 263.31 mm
# Step 5:
#   Current Position: [0.0722 0.0864 0.1252]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 261.42 mm
# Step 6:
#   Current Position: [0.0698 0.0854 0.127 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 258.57 mm
# Step 7:
#   Current Position: [0.0674 0.0855 0.1288]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 255.87 mm
# Step 8:
#   Current Position: [0.0651 0.0856 0.1292]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 253.57 mm
# Step 9:
#   Current Position: [0.0627 0.0848 0.1376]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 249.44 mm
# Step 10:
#   Current Position: [0.0603 0.0836 0.1496]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 244.96 mm
# Step 11:
#   Current Position: [0.057  0.0836 0.1574]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 240.73 mm
# Step 12:
#   Current Position: [0.053  0.0836 0.1618]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 236.34 mm
# Step 13:
#   Current Position: [0.0482 0.0828 0.1646]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 231.24 mm
# Step 14:
#   Current Position: [0.0439 0.0827 0.1663]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 226.84 mm
# Step 15:
#   Current Position: [0.0396 0.0826 0.1675]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 222.49 mm
# Step 16:
#   Current Position: [0.0353 0.0825 0.1682]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 218.18 mm
# Step 17:
#   Current Position: [0.0309 0.0813 0.1695]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 213.57 mm
# Step 18:
#   Current Position: [0.0264 0.08   0.1712]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 208.84 mm
# Step 19:
#   Current Position: [0.0215 0.0798 0.1707]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 204.00 mm
# Step 20:
#   Current Position: [0.0166 0.0791 0.1717]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 198.99 mm
# Step 21:
#   Current Position: [0.0118 0.0778 0.1711]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 194.11 mm
# Step 22:
#   Current Position: [0.0069 0.0775 0.1699]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 189.31 mm
# Step 23:
#   Current Position: [0.002  0.0761 0.168 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 184.44 mm
# Step 24:
#   Current Position: [-0.0028  0.0758  0.1685]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 179.62 mm
# Step 25:
#   Current Position: [-0.008   0.0746  0.1703]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 174.17 mm
# Step 26:
#   Current Position: [-0.0136  0.0743  0.1702]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 168.61 mm
# Step 27:
#   Current Position: [-0.0192  0.0729  0.1719]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 162.75 mm
# Step 28:
#   Current Position: [-0.0248  0.0723  0.1732]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 157.04 mm
# Step 29:
#   Current Position: [-0.0303  0.072   0.1727]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 151.61 mm
# Step 30:
#   Current Position: [-0.0359  0.0716  0.1738]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 145.94 mm
# Step 31:
#   Current Position: [-0.0415  0.0713  0.1736]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 140.38 mm
# Step 32:
#   Current Position: [-0.047   0.0698  0.1744]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 134.68 mm
# Step 33:
#   Current Position: [-0.0526  0.0687  0.174 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 129.03 mm
# Step 34:
#   Current Position: [-0.0581  0.0681  0.1729]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 123.61 mm
# Step 35:
#   Current Position: [-0.0646  0.0677  0.171 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 117.35 mm
# Step 36:
#   Current Position: [-0.0711  0.0662  0.1706]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 110.80 mm
# Step 37:
#   Current Position: [-0.0777  0.0658  0.1723]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 104.05 mm
# Step 38:
#   Current Position: [-0.0842  0.0642  0.1741]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 97.23 mm
# Step 39:
#   Current Position: [-0.0909  0.0638  0.1738]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 90.62 mm
# Step 40:
#   Current Position: [-0.0976  0.0622  0.175 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 83.67 mm
# Step 41:
#   Current Position: [-0.1042  0.0618  0.1746]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 77.17 mm
# Step 42:
#   Current Position: [-0.1113  0.0613  0.1735]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 70.29 mm
# Step 43:
#   Current Position: [-0.118   0.0609  0.174 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 63.61 mm
# Step 44:
#   Current Position: [-0.1247  0.0605  0.1737]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 57.08 mm
# Step 45:
#   Current Position: [-0.1313  0.06    0.1727]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 50.84 mm
# Step 46:
#   Current Position: [-0.138   0.0593  0.171 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 44.79 mm
# Step 47:
#   Current Position: [-0.1446  0.058   0.1685]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 39.35 mm
# Step 48:
#   Current Position: [-0.1512  0.0575  0.1689]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 33.24 mm
# Step 49:
#   Current Position: [-0.1577  0.0571  0.1709]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 26.65 mm
# Step 50:
#   Current Position: [-0.1643  0.0565  0.1707]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 21.39 mm
# Step 51:
#   Current Position: [-0.1708  0.0549  0.172 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 15.74 mm
# Step 52:
#   Current Position: [-0.1772  0.0534  0.1718]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 12.91 mm
# Step 53:
#   Current Position: [-0.1844  0.0518  0.1708]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 14.11 mm
# Step 54:
#   Current Position: [-0.1876  0.0513  0.1692]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 16.80 mm
# Step 55:
#   Current Position: [-0.1869  0.0509  0.1693]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 16.41 mm
# Step 56:
#   Current Position: [-0.1862  0.0505  0.1692]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 16.24 mm
# Step 57:
#   Current Position: [-0.1855  0.0499  0.1694]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 15.84 mm
# Step 58:
#   Current Position: [-0.1848  0.0495  0.1693]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 15.74 mm
# Step 59:
#   Current Position: [-0.185   0.0491  0.1684]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 16.70 mm
# Step 60:
#   Current Position: [-0.1869  0.0476  0.1688]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 17.25 mm
# Step 61:
#   Current Position: [-0.1882  0.0461  0.1694]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 17.67 mm
# Step 62:
#   Current Position: [-0.1878  0.0457  0.1716]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 15.80 mm
# Step 63:
#   Current Position: [-0.1875  0.0443  0.1715]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 16.29 mm
# Step 64:
#   Current Position: [-0.1873  0.0431  0.173 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 15.64 mm
# Step 65:
#   Current Position: [-0.1867  0.0416  0.1752]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 14.78 mm
# Step 66:
#   Current Position: [-0.1871  0.0412  0.1773]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 14.08 mm
# Step 67:
#   Current Position: [-0.187   0.0398  0.1795]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 14.19 mm
# Step 68:
#   Current Position: [-0.187   0.0393  0.1816]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 14.06 mm
# Step 69:
#   Current Position: [-0.1866  0.0379  0.1818]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 15.06 mm
# Step 70:
#   Current Position: [-0.187   0.0377  0.1821]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 15.37 mm
# Step 71:
#   Current Position: [-0.187   0.0363  0.182 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 16.63 mm
# Step 72:
#   Current Position: [-0.1865  0.0361  0.1834]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 16.48 mm
# Step 73:
#   Current Position: [-0.1861  0.0359  0.1833]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 16.52 mm
# Step 74:
#   Current Position: [-0.1856  0.0358  0.1824]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 16.51 mm
# Step 75:
#   Current Position: [-0.1861  0.0345  0.1809]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 18.10 mm
# Step 76:
#   Current Position: [-0.187   0.0333  0.1809]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 19.52 mm
# Step 77:
#   Current Position: [-0.187   0.032   0.1831]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 20.49 mm
# Step 78:
#   Current Position: [-0.1865  0.0307  0.1829]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 21.57 mm
# Step 79:
#   Current Position: [-0.1861  0.0295  0.1844]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 22.57 mm
# Step 80:
#   Current Position: [-0.1865  0.0282  0.1842]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 23.92 mm
# Step 81:
#   Current Position: [-0.1874  0.0281  0.1857]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 24.32 mm
# Step 82:
#   Current Position: [-0.1868  0.027   0.1855]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 25.19 mm
# Step 83:
#   Current Position: [-0.1862  0.0259  0.1847]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 26.08 mm
# Step 84:
#   Current Position: [-0.1856  0.026   0.1854]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 25.87 mm
# Step 85:
#   Current Position: [-0.1859  0.025   0.1869]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 27.02 mm
# Step 86:
#   Current Position: [-0.188   0.0251  0.189 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 27.74 mm
# Step 87:
#   Current Position: [-0.1876  0.0241  0.1888]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 28.54 mm
# Step 88:
#   Current Position: [-0.1869  0.0243  0.1902]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 28.44 mm
# Step 89:
#   Current Position: [-0.1862  0.0234  0.19  ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 29.09 mm
# Step 90:
#   Current Position: [-0.1864  0.0236  0.1914]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 29.26 mm
# Step 91:
#   Current Position: [-0.1872  0.0228  0.1911]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 30.12 mm
# Step 92:
#   Current Position: [-0.1871  0.0219  0.1915]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 31.04 mm
# Step 93:
#   Current Position: [-0.1866  0.0222  0.1936]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 31.22 mm
# Step 94:
#   Current Position: [-0.1861  0.0215  0.1956]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 32.42 mm
# Step 95:
#   Current Position: [-0.1856  0.0207  0.1975]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 33.77 mm
# Step 96:
#   Current Position: [-0.1851  0.0211  0.1995]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 34.17 mm
# Step 97:
#   Current Position: [-0.1855  0.0215  0.1991]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 33.70 mm
# Step 98:
#   Current Position: [-0.1878  0.0208  0.1981]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 34.35 mm
# Step 99:
#   Current Position: [-0.187   0.0202  0.1973]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 34.40 mm
# Step 100:
#   Current Position: [-0.1862  0.0207  0.197 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 33.68 mm
# Step 101:
#   Current Position: [-0.1864  0.0212  0.1978]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 33.58 mm
# Step 102:
#   Current Position: [-0.1871  0.0218  0.1974]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 33.02 mm
# Step 103:
#   Current Position: [-0.1866  0.0212  0.1964]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 33.07 mm
# Step 104:
#   Current Position: [-0.187   0.0218  0.1968]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 32.77 mm
# Step 105:
#   Current Position: [-0.187   0.0225  0.1964]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 31.98 mm
# Step 106:
#   Current Position: [-0.1869  0.0231  0.1976]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 31.91 mm
# Step 107:
#   Current Position: [-0.1873  0.0227  0.1994]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 33.14 mm
# Step 108:
#   Current Position: [-0.1867  0.0234  0.2012]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 33.29 mm
# Step 109:
#   Current Position: [-0.1861  0.0241  0.2029]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 33.51 mm
# Step 110:
#   Current Position: [-0.1865  0.0248  0.2032]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 33.19 mm
# Step 111:
#   Current Position: [-0.1872  0.0256  0.2026]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 32.36 mm
# Step 112:
#   Current Position: [-0.1867  0.0252  0.2037]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 33.20 mm
# Step 113:
#   Current Position: [-0.1861  0.0249  0.2031]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 32.98 mm
# Step 114:
#   Current Position: [-0.1856  0.0247  0.2018]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 32.32 mm
# Step 115:
#   Current Position: [-0.185   0.0253  0.1998]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 30.67 mm
# Step 116:
#   Current Position: [-0.1854  0.025   0.1972]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 29.76 mm
# Step 117:
#   Current Position: [-0.1867  0.0248  0.1961]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 29.74 mm
# Step 118:
#   Current Position: [-0.1874  0.0256  0.1972]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 29.67 mm
# Step 119:
#   Current Position: [-0.1868  0.0254  0.1966]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 29.44 mm
# Step 120:
#   Current Position: [-0.1862  0.0264  0.1963]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 28.30 mm
# Step 121:
#   Current Position: [-0.1865  0.0262  0.1957]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 28.30 mm
# Step 122:
#   Current Position: [-0.1872  0.0271  0.1967]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 28.11 mm
# Step 123:
#   Current Position: [-0.1871  0.0281  0.196 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 26.91 mm
# Step 124:
#   Current Position: [-0.1866  0.0291  0.1966]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 26.21 mm
# Step 125:
#   Current Position: [-0.187   0.0301  0.1975]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 25.92 mm
# Step 126:
#   Current Position: [-0.187   0.0311  0.1991]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 26.00 mm
# Step 127:
#   Current Position: [-0.1866  0.031   0.1992]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 26.03 mm
# Step 128:
#   Current Position: [-0.187   0.031   0.1994]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 26.25 mm
# Step 129:
#   Current Position: [-0.1865  0.032   0.1987]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 24.94 mm
# Step 130:
#   Current Position: [-0.1861  0.033   0.1978]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 23.54 mm
# Step 131:
#   Current Position: [-0.1865  0.0341  0.1967]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 22.17 mm
# Step 132:
#   Current Position: [-0.1874  0.0352  0.1949]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 20.63 mm
# Step 133:
#   Current Position: [-0.1872  0.036   0.1947]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 19.84 mm
# Step 134:
#   Current Position: [-0.1872  0.0371  0.1962]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 19.88 mm
# Step 135:
#   Current Position: [-0.1866  0.0371  0.1977]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 20.62 mm
# Step 136:
#   Current Position: [-0.1861  0.0374  0.1988]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 21.01 mm
# Step 137:
#   Current Position: [-0.1856  0.0374  0.2002]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 21.87 mm
# Step 138:
#   Current Position: [-0.1855  0.0374  0.1999]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 21.62 mm
# Step 139:
#   Current Position: [-0.1859  0.0385  0.1991]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 20.46 mm
# Step 140:
#   Current Position: [-0.1871  0.0396  0.1988]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 19.96 mm
# Step 141:
#   Current Position: [-0.1871  0.0397  0.198 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 19.32 mm
# Step 142:
#   Current Position: [-0.1869  0.0397  0.1987]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 19.76 mm
# Step 143:
#   Current Position: [-0.1871  0.0408  0.2   ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 20.21 mm
# Step 144:
#   Current Position: [-0.187   0.0409  0.1992]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 19.50 mm
# Step 145:
#   Current Position: [-0.1866  0.0409  0.1977]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 18.22 mm
# Step 146:
#   Current Position: [-0.1861  0.0421  0.1977]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 17.39 mm
# Step 147:
#   Current Position: [-0.1856  0.0421  0.1983]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 17.69 mm
# Step 148:
#   Current Position: [-0.1851  0.0422  0.1973]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 16.70 mm
# Step 149:
#   Current Position: [-0.1856  0.0433  0.198 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 16.86 mm
# Step 150:
#   Current Position: [-0.1879  0.0434  0.197 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 16.94 mm
# Step 151:
#   Current Position: [-0.1871  0.0435  0.1976]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 17.01 mm
# Step 152:
#   Current Position: [-0.1872  0.0435  0.1966]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 16.27 mm
# Step 153:
#   Current Position: [-0.1871  0.0441  0.1949]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 14.67 mm
# Step 154:
#   Current Position: [-0.1866  0.0453  0.1926]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 12.20 mm
# Step 155:
#   Current Position: [-0.187   0.0453  0.1918]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 11.89 mm
# Step 156:
#   Current Position: [-0.187   0.0465  0.1916]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 11.21 mm
# Step 157:
#   Current Position: [-0.187   0.0476  0.1907]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 10.19 mm
# Step 158:
#   Current Position: [-0.1865  0.0488  0.1912]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 9.83 mm
# Step 159:
#   Current Position: [-0.187   0.0489  0.1903]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 9.55 mm
# Step 160:
#   Current Position: [-0.1875  0.05    0.1896]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 9.29 mm
# Step 161:
#   Current Position: [-0.1868  0.0501  0.1886]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 8.15 mm
# Step 162:
#   Current Position: [-0.1862  0.0501  0.1892]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 8.02 mm
# Step 163:
#   Current Position: [-0.1864  0.0502  0.1882]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 7.59 mm
# Step 164:
#   Current Position: [-0.1872  0.0514  0.1888]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 8.51 mm
# Step 165:
#   Current Position: [-0.1871  0.0525  0.1901]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 9.29 mm
# Step 166:
#   Current Position: [-0.1871  0.0526  0.1913]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 10.11 mm
# Step 167:
#   Current Position: [-0.1866  0.0526  0.1903]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 9.06 mm
# Step 168:
#   Current Position: [-0.1861  0.0526  0.1886]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 7.61 mm
# Step 169:
#   Current Position: [-0.1865  0.0529  0.1862]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 6.97 mm
# Step 170:
#   Current Position: [-0.1873  0.0529  0.1845]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 7.46 mm
# Step 171:
#   Current Position: [-0.1872  0.0537  0.1849]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 7.61 mm
# Step 172:
#   Current Position: [-0.1871  0.0548  0.1839]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 7.92 mm
# Step 173:
#   Current Position: [-0.1866  0.0559  0.1823]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 8.28 mm
# Step 174:
#   Current Position: [-0.1861  0.056   0.1799]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 8.83 mm
# Step 175:
#   Current Position: [-0.1865  0.0569  0.1769]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 11.28 mm
# Step 176:
#   Current Position: [-0.1873  0.0569  0.1731]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 14.43 mm
# Step 177:
#   Current Position: [-0.1867  0.058   0.1709]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 16.35 mm
# Step 178:
#   Current Position: [-0.1861  0.058   0.1702]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 16.69 mm
# Step 179:
#   Current Position: [-0.1865  0.0579  0.169 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 17.82 mm
# Step 180:
#   Current Position: [-0.1873  0.059   0.1701]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 17.66 mm
# Step 181:
#   Current Position: [-0.1867  0.0589  0.1716]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 16.19 mm
# Step 182:
#   Current Position: [-0.1861  0.06    0.1708]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 17.13 mm
# Step 183:
#   Current Position: [-0.1856  0.0599  0.1716]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 16.28 mm
# Step 184:
#   Current Position: [-0.1859  0.0609  0.1731]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 15.85 mm
# Step 185:
#   Current Position: [-0.1881  0.0608  0.1723]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 17.27 mm
# Step 186:
#   Current Position: [-0.1877  0.0608  0.1708]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 18.16 mm
# Step 187:
#   Current Position: [-0.1875  0.0618  0.1707]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 18.70 mm
# Step 188:
#   Current Position: [-0.1868  0.062   0.1722]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 17.49 mm
# Step 189:
#   Current Position: [-0.1871  0.0623  0.1723]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 17.72 mm
# Step 190:
#   Current Position: [-0.1866  0.0621  0.1738]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 16.41 mm
# Step 191:
#   Current Position: [-0.1861  0.0619  0.1751]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 15.28 mm
# Step 192:
#   Current Position: [-0.1865  0.0617  0.1744]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 15.73 mm
# Step 193:
#   Current Position: [-0.1873  0.0616  0.173 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 16.90 mm
# Step 194:
#   Current Position: [-0.1872  0.0614  0.171 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 18.14 mm
# Step 195:
#   Current Position: [-0.1867  0.0623  0.1706]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 18.76 mm
# Step 196:
#   Current Position: [-0.1862  0.0621  0.1715]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 17.82 mm
# Step 197:
#   Current Position: [-0.1858  0.0629  0.1708]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 18.68 mm
# Step 198:
#   Current Position: [-0.1863  0.0638  0.1718]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 18.73 mm
# Step 199:
#   Current Position: [-0.1872  0.0647  0.1734]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 18.69 mm
# Step 200:
#   Current Position: [-0.1871  0.0645  0.1728]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 18.87 mm
# Step 201:
#   Current Position: [-0.1869  0.0642  0.1715]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 19.41 mm
# Step 202:
#   Current Position: [-0.1871  0.065   0.1695]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 21.34 mm
# Step 203:
#   Current Position: [-0.1866  0.0658  0.1695]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 21.71 mm
# Step 204:
#   Current Position: [-0.1861  0.0655  0.1689]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 21.78 mm
# Step 205:
#   Current Position: [-0.1858  0.0652  0.1691]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 21.36 mm
# Step 206:
#   Current Position: [-0.1867  0.0648  0.1709]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 20.14 mm
# Step 207:
#   Current Position: [-0.1877  0.0645  0.1704]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 20.62 mm
# Step 208:
#   Current Position: [-0.1874  0.0648  0.1692]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 21.53 mm
# Step 209:
#   Current Position: [-0.1868  0.0645  0.1693]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 21.07 mm
# Step 210:
#   Current Position: [-0.1862  0.0652  0.1691]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 21.47 mm
# Step 211:
#   Current Position: [-0.1855  0.0648  0.1702]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 20.25 mm
# Step 212:
#   Current Position: [-0.1854  0.0644  0.172 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 18.74 mm
# Step 213:
#   Current Position: [-0.1857  0.0651  0.1715]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 19.64 mm
# Step 214:
#   Current Position: [-0.1861  0.0646  0.1726]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 18.71 mm
# Step 215:
#   Current Position: [-0.1873  0.065   0.1722]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 19.66 mm
# Step 216:
#   Current Position: [-0.1867  0.0657  0.1733]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 19.30 mm
# Step 217:
#   Current Position: [-0.1871  0.0663  0.1752]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 18.92 mm
# Step 218:
#   Current Position: [-0.1866  0.0658  0.1749]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 18.49 mm
# Step 219:
#   Current Position: [-0.1865  0.0664  0.1762]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 18.33 mm
# Step 220:
#   Current Position: [-0.1878  0.067   0.1781]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 18.60 mm
# Step 221:
#   Current Position: [-0.1871  0.0677  0.1799]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 18.43 mm
# Step 222:
#   Current Position: [-0.1872  0.0671  0.1816]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 17.60 mm
# Step 223:
#   Current Position: [-0.1871  0.0666  0.1834]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 16.93 mm
# Step 224:
#   Current Position: [-0.1871  0.066   0.1852]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 16.40 mm
# Step 225:
#   Current Position: [-0.1866  0.0654  0.1869]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 15.84 mm
# Step 226:
#   Current Position: [-0.1861  0.0659  0.1865]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 16.03 mm
# Step 227:
#   Current Position: [-0.1856  0.0653  0.187 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 15.38 mm
# Step 228:
#   Current Position: [-0.1851  0.0658  0.1865]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 15.59 mm
# Step 229:
#   Current Position: [-0.1856  0.0657  0.1875]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 15.85 mm
# Step 230:
#   Current Position: [-0.1869  0.0652  0.1886]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 16.17 mm
# Step 231:
#   Current Position: [-0.1877  0.0645  0.1881]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 15.81 mm
# Step 232:
#   Current Position: [-0.1869  0.065   0.1869]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 15.62 mm
# Step 233:
#   Current Position: [-0.1871  0.0652  0.185 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 15.67 mm
# Step 234:
#   Current Position: [-0.1866  0.0654  0.1824]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 15.72 mm
# Step 235:
#   Current Position: [-0.187   0.0647  0.1791]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 16.00 mm
# Step 236:
#   Current Position: [-0.187   0.0651  0.1774]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 16.94 mm
# Step 237:
#   Current Position: [-0.1866  0.0655  0.177 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 17.28 mm
# Step 238:
#   Current Position: [-0.1861  0.0648  0.1758]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 17.07 mm
# Step 239:
#   Current Position: [-0.1865  0.064   0.1763]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 16.35 mm
# Step 240:
#   Current Position: [-0.1874  0.0633  0.1781]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 15.40 mm
# Step 241:
#   Current Position: [-0.1868  0.0625  0.1777]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 14.66 mm
# Step 242:
#   Current Position: [-0.1871  0.0629  0.1766]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 15.61 mm
# Step 243:
#   Current Position: [-0.187   0.0621  0.1749]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 15.91 mm
# Step 244:
#   Current Position: [-0.187   0.0625  0.1751]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 16.07 mm
# Step 245:
#   Current Position: [-0.1866  0.0617  0.1747]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 15.59 mm
# Step 246:
#   Current Position: [-0.1861  0.0621  0.1742]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 15.97 mm
# Step 247:
#   Current Position: [-0.1865  0.062   0.176 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 15.00 mm
# Step 248:
#   Current Position: [-0.1874  0.0623  0.1756]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 15.83 mm
# Step 249:
#   Current Position: [-0.1872  0.0615  0.1746]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 15.78 mm
# Step 250:
#   Current Position: [-0.1867  0.0616  0.1751]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 15.32 mm
# Step 251:
#   Current Position: [-0.187   0.0618  0.1757]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 15.25 mm
# Step 252:
#   Current Position: [-0.1866  0.0621  0.1777]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 14.26 mm
# Step 253:
#   Current Position: [-0.1861  0.0624  0.1796]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 13.51 mm
# Step 254:
#   Current Position: [-0.1856  0.0627  0.1815]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 13.03 mm
# Step 255:
#   Current Position: [-0.1851  0.0618  0.1811]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 12.12 mm
# Step 256:
#   Current Position: [-0.1847  0.0621  0.182 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 12.03 mm
# Step 257:
#   Current Position: [-0.1842  0.0612  0.1817]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 11.09 mm
# Step 258:
#   Current Position: [-0.1846  0.0603  0.1806]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 10.77 mm
# Step 259:
#   Current Position: [-0.1866  0.0594  0.1811]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 10.93 mm
# Step 260:
#   Current Position: [-0.1878  0.0597  0.1831]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 11.54 mm
# Step 261:
#   Current Position: [-0.187   0.0599  0.185 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 11.15 mm
# Step 262:
#   Current Position: [-0.1872  0.0601  0.1869]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 11.71 mm
# Step 263:
#   Current Position: [-0.1866  0.0604  0.1887]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 12.14 mm
# Step 264:
#   Current Position: [-0.1861  0.0606  0.1906]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 12.86 mm
# Step 265:
#   Current Position: [-0.1865  0.0597  0.1901]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 12.17 mm
# Step 266:
#   Current Position: [-0.1873  0.0588  0.1906]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 12.28 mm
# Step 267:
#   Current Position: [-0.1867  0.0589  0.1902]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 11.79 mm
# Step 268:
#   Current Position: [-0.1871  0.0591  0.1897]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 11.92 mm
# Step 269:
#   Current Position: [-0.1866  0.0582  0.1893]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 10.84 mm
# Step 270:
#   Current Position: [-0.1862  0.0573  0.1904]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 10.64 mm
# Step 271:
#   Current Position: [-0.1869  0.0574  0.1922]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 12.21 mm
# Step 272:
#   Current Position: [-0.1877  0.0572  0.1917]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 12.27 mm
# Step 273:
#   Current Position: [-0.187   0.0574  0.1905]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 11.23 mm
# Step 274:
#   Current Position: [-0.1862  0.0564  0.1891]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 9.42 mm
# Step 275:
#   Current Position: [-0.1864  0.0554  0.1891]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 9.05 mm
# Step 276:
#   Current Position: [-0.1871  0.0556  0.1909]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 10.67 mm
# Step 277:
#   Current Position: [-0.1866  0.0555  0.1904]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 9.98 mm
# Step 278:
#   Current Position: [-0.187   0.0545  0.1892]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 9.17 mm
# Step 279:
#   Current Position: [-0.1866  0.0536  0.1895]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 8.76 mm
# Step 280:
#   Current Position: [-0.1861  0.0526  0.189 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 7.85 mm
# Step 281:
#   Current Position: [-0.1865  0.0516  0.1901]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 8.76 mm
# Step 282:
#   Current Position: [-0.1874  0.0518  0.1896]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 9.15 mm
# Step 283:
#   Current Position: [-0.1872  0.052   0.1884]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 8.34 mm
# Step 284:
#   Current Position: [-0.1871  0.0518  0.1888]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 8.45 mm
# Step 285:
#   Current Position: [-0.1871  0.052   0.1882]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 8.15 mm
# Step 286:
#   Current Position: [-0.1871  0.052   0.187 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 7.64 mm
# Step 287:
#   Current Position: [-0.1866  0.0521  0.1874]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 7.35 mm
# Step 288:
#   Current Position: [-0.187   0.0512  0.1869]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 7.47 mm
# Step 289:
#   Current Position: [-0.1866  0.0514  0.1873]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 7.26 mm
# Step 290:
#   Current Position: [-0.1861  0.0516  0.1891]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 7.80 mm
# Step 291:
#   Current Position: [-0.1856  0.0518  0.1885]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 7.05 mm
# Step 292:
#   Current Position: [-0.1852  0.0519  0.1873]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 6.06 mm
# Step 293:
#   Current Position: [-0.1856  0.0521  0.1876]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 6.58 mm
# Step 294:
#   Current Position: [-0.1879  0.0523  0.1887]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 9.12 mm
# Step 295:
#   Current Position: [-0.1871  0.0518  0.1882]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 8.14 mm
# Step 296:
#   Current Position: [-0.1872  0.0516  0.1892]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 8.74 mm
# Step 297:
#   Current Position: [-0.1867  0.0507  0.1886]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 8.00 mm
# Step 298:
#   Current Position: [-0.1863  0.0498  0.1897]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 8.46 mm
# Step 299:
#   Current Position: [-0.1861  0.0494  0.1891]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 8.01 mm
# Step 300:
#   Current Position: [-0.1868  0.0485  0.1879]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 8.18 mm
# Step 301:
#   Current Position: [-0.1877  0.0475  0.1875]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 9.14 mm
# Step 302:
#   Current Position: [-0.187   0.0477  0.187 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 8.30 mm
# Step 303:
#   Current Position: [-0.1865  0.048   0.1857]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 7.38 mm
# Step 304:
#   Current Position: [-0.1872  0.0482  0.1838]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 7.79 mm
# Step 305:
#   Current Position: [-0.1871  0.0484  0.1834]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 7.65 mm
# Step 306:
#   Current Position: [-0.1866  0.0486  0.1829]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 7.19 mm
# Step 307:
#   Current Position: [-0.187   0.0477  0.1828]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 7.94 mm
# Step 308:
#   Current Position: [-0.187   0.0469  0.1823]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 8.42 mm
# Step 309:
#   Current Position: [-0.187   0.0466  0.1811]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 8.92 mm
# Step 310:
#   Current Position: [-0.187   0.0457  0.1814]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 9.33 mm
# Step 311:
#   Current Position: [-0.1865  0.0449  0.1824]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 9.23 mm
# Step 312:
#   Current Position: [-0.187   0.044   0.1826]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 10.17 mm
# Step 313:
#   Current Position: [-0.187   0.0443  0.1844]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 9.83 mm
# Step 314:
#   Current Position: [-0.187   0.0435  0.1861]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 10.58 mm
# Step 315:
#   Current Position: [-0.1866  0.0427  0.1856]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 10.86 mm
# Step 316:
#   Current Position: [-0.1871  0.043   0.1843]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 10.85 mm
# Step 317:
#   Current Position: [-0.1866  0.0422  0.1847]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 11.18 mm
# Step 318:
#   Current Position: [-0.187   0.0414  0.1864]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 12.25 mm
# Step 319:
#   Current Position: [-0.1866  0.0417  0.188 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 12.18 mm
# Step 320:
#   Current Position: [-0.1861  0.041   0.1884]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 12.61 mm
# Step 321:
#   Current Position: [-0.1856  0.0409  0.1901]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 13.14 mm
# Step 322:
#   Current Position: [-0.1852  0.0412  0.1895]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 12.47 mm
# Step 323:
#   Current Position: [-0.1847  0.0405  0.1883]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 12.40 mm
# Step 324:
#   Current Position: [-0.1851  0.0409  0.1863]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 11.70 mm
# Step 325:
#   Current Position: [-0.1871  0.0402  0.1849]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 13.12 mm
# Step 326:
#   Current Position: [-0.187   0.0395  0.1841]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 13.65 mm
# Step 327:
#   Current Position: [-0.187   0.0388  0.1838]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 14.26 mm
# Step 328:
#   Current Position: [-0.1866  0.0392  0.1855]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 13.77 mm
# Step 329:
#   Current Position: [-0.187   0.0396  0.185 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 13.58 mm
# Step 330:
#   Current Position: [-0.1865  0.0401  0.186 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 13.00 mm
# Step 331:
#   Current Position: [-0.187   0.0406  0.1854]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 12.77 mm
# Step 332:
#   Current Position: [-0.1866  0.0399  0.1841]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 13.10 mm
# Step 333:
#   Current Position: [-0.1873  0.0404  0.1844]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 13.05 mm
# Step 334:
#   Current Position: [-0.1872  0.0409  0.1839]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 12.58 mm
# Step 335:
#   Current Position: [-0.1867  0.0403  0.1826]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 12.91 mm
# Step 336:
#   Current Position: [-0.187   0.0397  0.1828]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 13.55 mm
# Step 337:
#   Current Position: [-0.187   0.0402  0.1823]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 13.19 mm
# Step 338:
#   Current Position: [-0.187   0.0396  0.1811]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 13.91 mm
# Step 339:
#   Current Position: [-0.187   0.0396  0.1814]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 13.85 mm
# Step 340:
#   Current Position: [-0.1865  0.039   0.1809]
# ...
# Step 4141:
#   Current Position: [-0.1832  0.0464  0.1949]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 12.16 mm
# Step 4142:
#   Current Position: [-0.1836  0.0456  0.1956]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 13.20 mm
# Step 4143:
#   Current Position: [-0.183   0.0449  0.1971]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 14.67 mm
# Step 4144:
#   Current Position: [-0.1833  0.0441  0.1985]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 16.31 mm
# Step 4145:
#   Current Position: [-0.1827  0.0444  0.1976]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 15.27 mm
# Step 4146:
#   Current Position: [-0.1821  0.0447  0.196 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 13.64 mm
# Step 4147:
#   Current Position: [-0.1815  0.0451  0.196 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 13.38 mm
# Step 4148:
#   Current Position: [-0.1809  0.0444  0.1952]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 12.98 mm
# Step 4149:
#   Current Position: [-0.1812  0.0448  0.1936]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 11.45 mm
# Step 4150:
#   Current Position: [-0.1815  0.0452  0.1936]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 11.26 mm
# Step 4151:
#   Current Position: [-0.1814  0.0456  0.1927]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 10.29 mm
# Step 4152:
#   Current Position: [-0.1808  0.046   0.1934]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 10.61 mm
# Step 4153:
#   Current Position: [-0.1812  0.0459  0.1933]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 10.61 mm
# Step 4154:
#   Current Position: [-0.1806  0.0452  0.1946]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 12.03 mm
# Step 4155:
#   Current Position: [-0.1809  0.0456  0.194 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 11.33 mm
# Step 4156:
#   Current Position: [-0.1803  0.0449  0.1936]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 11.34 mm
# Step 4157:
#   Current Position: [-0.18    0.0453  0.195 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 12.32 mm
# Step 4158:
#   Current Position: [-0.1794  0.0458  0.1963]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 13.28 mm
# Step 4159:
#   Current Position: [-0.1797  0.0457  0.1953]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 12.40 mm
# Step 4160:
#   Current Position: [-0.1791  0.045   0.1936]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 11.32 mm
# Step 4161:
#   Current Position: [-0.1786  0.0444  0.1928]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 11.08 mm
# Step 4162:
#   Current Position: [-0.178   0.0437  0.1919]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 10.96 mm
# Step 4163:
#   Current Position: [-0.1783  0.044   0.1902]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 9.56 mm
# Step 4164:
#   Current Position: [-0.1777  0.0444  0.1878]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 8.07 mm
# Step 4165:
#   Current Position: [-0.1772  0.0438  0.1848]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 7.98 mm
# Step 4166:
#   Current Position: [-0.1775  0.0433  0.1833]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 8.38 mm
# Step 4167:
#   Current Position: [-0.1779  0.0438  0.1833]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 7.79 mm
# Step 4168:
#   Current Position: [-0.1782  0.0443  0.1847]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 7.19 mm
# Step 4169:
#   Current Position: [-0.1786  0.0448  0.1838]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 6.61 mm
# Step 4170:
#   Current Position: [-0.179   0.0453  0.1844]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 6.03 mm
# Step 4171:
#   Current Position: [-0.1784  0.0447  0.1858]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 6.92 mm
# Step 4172:
#   Current Position: [-0.1788  0.0441  0.1849]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 7.27 mm
# Step 4173:
#   Current Position: [-0.1791  0.0439  0.1832]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 7.46 mm
# Step 4174:
#   Current Position: [-0.1786  0.0445  0.1832]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 6.96 mm
# Step 4175:
#   Current Position: [-0.178   0.045   0.1823]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 6.83 mm
# Step 4176:
#   Current Position: [-0.1784  0.0444  0.1807]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 7.85 mm
# Step 4177:
#   Current Position: [-0.1778  0.0439  0.1806]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 8.47 mm
# Step 4178:
#   Current Position: [-0.1782  0.0433  0.1798]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 9.26 mm
# Step 4179:
#   Current Position: [-0.1786  0.0427  0.1804]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 9.45 mm
# Step 4180:
#   Current Position: [-0.178   0.0421  0.1796]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 10.43 mm
# Step 4181:
#   Current Position: [-0.1777  0.0416  0.1786]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 11.39 mm
# Step 4182:
#   Current Position: [-0.1772  0.0421  0.1778]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 11.51 mm
# Step 4183:
#   Current Position: [-0.1766  0.0416  0.1764]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 12.87 mm
# Step 4184:
#   Current Position: [-0.1768  0.0414  0.1743]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 14.33 mm
# Step 4185:
#   Current Position: [-0.177   0.042   0.1739]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 14.17 mm
# Step 4186:
#   Current Position: [-0.1764  0.0419  0.1736]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 14.59 mm
# Step 4187:
#   Current Position: [-0.1768  0.0426  0.1728]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 14.67 mm
# Step 4188:
#   Current Position: [-0.1763  0.0421  0.1714]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 16.17 mm
# Step 4189:
#   Current Position: [-0.1759  0.0416  0.1713]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 16.63 mm
# Step 4190:
#   Current Position: [-0.1763  0.0423  0.1718]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 15.74 mm
# Step 4191:
#   Current Position: [-0.1758  0.0429  0.1711]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 16.10 mm
# Step 4192:
#   Current Position: [-0.1753  0.0436  0.1704]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 16.47 mm
# Step 4193:
#   Current Position: [-0.1748  0.0443  0.172 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 14.98 mm
# Step 4194:
#   Current Position: [-0.1752  0.045   0.1736]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 13.22 mm
# Step 4195:
#   Current Position: [-0.1748  0.0456  0.1729]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 13.67 mm
# Step 4196:
#   Current Position: [-0.1743  0.0461  0.172 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 14.43 mm
# Step 4197:
#   Current Position: [-0.1738  0.0468  0.1708]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 15.43 mm
# Step 4198:
#   Current Position: [-0.1734  0.0475  0.1703]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 15.85 mm
# Step 4199:
#   Current Position: [-0.1738  0.0481  0.1703]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 15.56 mm
# Step 4200:
#   Current Position: [-0.1735  0.0488  0.1697]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 16.09 mm
# Step 4201:
#   Current Position: [-0.174   0.0484  0.1684]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 17.15 mm
# Step 4202:
#   Current Position: [-0.1735  0.0488  0.1688]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 16.91 mm
# Step 4203:
#   Current Position: [-0.174   0.0483  0.1692]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 16.44 mm
# Step 4204:
#   Current Position: [-0.1745  0.049   0.1694]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 15.96 mm
# Step 4205:
#   Current Position: [-0.175   0.0495  0.1688]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 16.30 mm
# Step 4206:
#   Current Position: [-0.1755  0.0501  0.1691]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 15.81 mm
# Step 4207:
#   Current Position: [-0.1751  0.0497  0.1708]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 14.37 mm
# Step 4208:
#   Current Position: [-0.1747  0.0504  0.1703]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 14.92 mm
# Step 4209:
#   Current Position: [-0.1752  0.0499  0.1691]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 15.92 mm
# Step 4210:
#   Current Position: [-0.1757  0.0495  0.1693]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 15.62 mm
# Step 4211:
#   Current Position: [-0.1762  0.0501  0.1688]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 15.91 mm
# Step 4212:
#   Current Position: [-0.1758  0.0508  0.17  ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 14.83 mm
# Step 4213:
#   Current Position: [-0.1754  0.0503  0.1708]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 14.21 mm
# Step 4214:
#   Current Position: [-0.1759  0.0499  0.1726]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 12.39 mm
# Step 4215:
#   Current Position: [-0.1764  0.0498  0.1744]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 10.55 mm
# Step 4216:
#   Current Position: [-0.1761  0.0494  0.1758]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 9.46 mm
# Step 4217:
#   Current Position: [-0.1766  0.0489  0.177 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 8.32 mm
# Step 4218:
#   Current Position: [-0.1771  0.0485  0.1788]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 6.73 mm
# Step 4219:
#   Current Position: [-0.1776  0.0481  0.1806]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 5.36 mm
# Step 4220:
#   Current Position: [-0.1773  0.0476  0.1824]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 4.89 mm
# Step 4221:
#   Current Position: [-0.1778  0.0475  0.1819]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 4.93 mm
# Step 4222:
#   Current Position: [-0.1774  0.0471  0.1819]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 5.42 mm
# Step 4223:
#   Current Position: [-0.177   0.0478  0.1837]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 4.61 mm
# Step 4224:
#   Current Position: [-0.1767  0.0485  0.1832]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 4.43 mm
# Step 4225:
#   Current Position: [-0.1772  0.0492  0.1843]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 3.49 mm
# Step 4226:
#   Current Position: [-0.1777  0.0499  0.1838]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 2.72 mm
# Step 4227:
#   Current Position: [-0.1783  0.0506  0.1826]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 2.45 mm
# Step 4228:
#   Current Position: [-0.1779  0.0502  0.1823]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 3.04 mm
# Step 4229:
#   Current Position: [-0.1775  0.0505  0.1841]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 2.64 mm
# Step 4230:
#   Current Position: [-0.1776  0.0512  0.1859]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 2.97 mm
# Step 4231:
#   Current Position: [-0.1773  0.0516  0.1854]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 3.01 mm
# Step 4232:
#   Current Position: [-0.1778  0.0511  0.1842]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 2.24 mm
# Step 4233:
#   Current Position: [-0.1774  0.0507  0.1823]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 3.30 mm
# Step 4234:
#   Current Position: [-0.1771  0.0514  0.1797]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 5.38 mm
# Step 4235:
#   Current Position: [-0.1776  0.051   0.1765]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 8.08 mm
# Step 4236:
#   Current Position: [-0.1773  0.0517  0.1746]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 10.00 mm
# Step 4237:
#   Current Position: [-0.1772  0.0523  0.1747]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 9.98 mm
# Step 4238:
#   Current Position: [-0.1768  0.0519  0.1756]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 9.22 mm
# Step 4239:
#   Current Position: [-0.1769  0.0515  0.1774]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 7.50 mm
# Step 4240:
#   Current Position: [-0.1766  0.0511  0.1793]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 5.99 mm
# Step 4241:
#   Current Position: [-0.177   0.0506  0.1811]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 4.39 mm
# Step 4242:
#   Current Position: [-0.1776  0.0513  0.1821]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 3.22 mm
# Step 4243:
#   Current Position: [-0.1781  0.0509  0.1839]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 1.99 mm
# Step 4244:
#   Current Position: [-0.1778  0.051   0.1835]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 2.36 mm
# Step 4245:
#   Current Position: [-0.1784  0.0507  0.1836]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 1.82 mm
# Step 4246:
#   Current Position: [-0.179   0.0512  0.1832]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 1.44 mm
# Step 4247:
#   Current Position: [-0.1795  0.0508  0.1823]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 2.03 mm
# Step 4248:
#   Current Position: [-0.1792  0.0504  0.1831]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 1.62 mm
# Step 4249:
#   Current Position: [-0.1798  0.0511  0.183 ]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 1.23 mm
# Step 4250:
#   Current Position: [-0.1794  0.0507  0.1838]
#   Goal Position: [-0.18003549  0.05123494  0.18420415]
#   Distance to Goal: 0.92 mm
# Goal Reached!
# numActiveThreads = 0
# stopping threads
# Thread with taskId 0 exiting
# Thread TERMINATED
# destroy semaphore
# semaphore destroyed
# destroy main semaphore
# main semaphore destroyed
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
