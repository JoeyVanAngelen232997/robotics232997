# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
from sim_class import Simulation

# Create the class
class OT2Env(gym.Env):
    def __init__(self, render=True, max_steps=1000):
        super(OT2Env, self).__init__()
        self.render = render
        self.max_steps = max_steps

        # Create the simulation environment
        self.sim = Simulation(num_agents=1, render=self.render)

        # Set the maximum values according to the working environment.
        self.x_min, self.x_max = -0.187, 0.2531
        self.y_min, self.y_max = -0.1705, 0.2195
        self.z_min, self.z_max = 0.1195, 0.2895
        # Define action and observation spaces
        self.action_space = spaces.Box(low=-1.0, high=1.0, shape=(3,), dtype=np.float32)
        self.observation_space = spaces.Box(
            low=np.array([self.x_min, self.y_min, self.z_min, -self.x_max, -self.y_max, -self.z_max], dtype=np.float32),
            high=np.array([self.x_max, self.y_max, self.z_max, self.x_max, self.y_max, self.z_max], dtype=np.float32),
            dtype=np.float32
        )

        # Keep track of the step amount
        self.steps = 0

    def reset(self, seed=None):
        # Set a seed if it was not set yet
        if seed is not None:
            np.random.seed(seed)

        # Randomise the goal position
        x = np.random.uniform(self.x_min, self.x_max)
        y = np.random.uniform(self.y_min, self.y_max)
        z = np.random.uniform(self.z_min, self.z_max)
        # Set a random goal position
        self.goal_position = np.array([x, y, z])
        # Call reset function
        observation = self.sim.reset(num_agents=1)
        # Set the observation.
        observation = np.concatenate(
            (
                self.sim.get_pipette_position(self.sim.robotIds[0]), 
                self.goal_position
            ), axis=0
        ).astype(np.float32) 

        # Reset the number of steps
        self.steps = 0

        info = {}

        return observation, info

    def step(self, action):
        # set the actions
        action = np.append(np.array(action, dtype=np.float32), 0)
        # Call the step function
        observation = self.sim.run([action])
        pipette_position = self.sim.get_pipette_position(self.sim.robotIds[0])
        # Process observation
        observation = np.array(pipette_position, dtype=np.float32)
        # Calculate the agent's reward
        distance = np.linalg.norm(np.array(pipette_position) - np.array(self.goal_position))
        reward = -distance
        
        # Check if the agent reaches within the threshold of the goal position
        if np.linalg.norm(pipette_position - self.goal_position) <= 0.001:
            terminated = True
        else:
            terminated = False

        # Check if episode should be truncated
        if self.steps >= self.max_steps:
            truncated = True
        else:
            truncated = False
        observation = np.concatenate((pipette_position, self.goal_position), axis=0).astype(np.float32)
        info = {}

        # Update the amount of steps
        self.steps += 1

        return observation, reward, terminated, truncated, info

    def render(self, mode='human'):
        pass
    
    def close(self):
        self.sim.close()

# %%
from stable_baselines3 import PPO  # Replace PPO with your RL algorithm
import numpy as np


# Path to the trained model
model_path = "C:\\Users\\jarro\\Documents\\GitHub\\Reinforcement learning\\model.zip"  # Replace with the actual path to your model

# Load the trained model
model = PPO.load(model_path)  # Replace PPO with the correct algorithm

# Initialize the environment
env = OT2Env(render=True)  # Initialize the environment with rendering disabled

# Test the trained model
def test_model(env, model, max_steps=1000):
    """
    Test the trained model to move the pipette to the target location.

    Args:
        env: The testing environment.
        model: The trained RL model.
        max_steps: Maximum number of steps for the test.

    Returns:
        None
    """
    # Reset the environment
    obs, _ = env.reset()

    print(f"Goal Position: {env.goal_position}")

    for step in range(max_steps):
        # Predict the action for the current state
        action, _ = model.predict(obs, deterministic=True)  # Use deterministic=True for testing
        obs, _, terminated, truncated, _ = env.step(action)  # Execute the action

        # Calculate the accuracy (distance to the goal) in mm
        current_position = obs[:3]  # Extract the current position from the observation
        goal_position = env.goal_position
        distance_to_goal = np.linalg.norm(goal_position - current_position) * 1000  # Convert to mm

        # Print debug information
        print(f"Step {step + 1}:")
        print(f"  Current Position: {current_position}")
        print(f"  Goal Position: {goal_position}")
        print(f"  Distance to Goal: {distance_to_goal:.2f} mm")

        # Check if the goal is reached or the environment signals termination
        if terminated or distance_to_goal <= 1.0:  # 1 mm accuracy requirement
            print("Goal Reached!" if distance_to_goal <= 1.0 else "Environment Terminated!")
            break

    # Close the environment
    env.close()


# Run the test
if __name__ == "__main__":
    test_model(env, model, max_steps=10000)
# Out:
# Goal Position: [0.23310898 0.06773573 0.18234673]
# Step 1:
#   Current Position: [0.07345802 0.09005769 0.12024033]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 172.75 mm
# Step 2:
#   Current Position: [0.07437398 0.09089912 0.12097898]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 171.75 mm
# Step 3:
#   Current Position: [0.07574775 0.09170712 0.12172438]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 170.33 mm
# Step 4:
#   Current Position: [0.07757922 0.09247853 0.12248037]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 168.48 mm
# Step 5:
#   Current Position: [0.07986826 0.09321105 0.12325046]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 166.20 mm
# Step 6:
#   Current Position: [0.0826147  0.0939016  0.12403858]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 163.50 mm
# Step 7:
#   Current Position: [0.08581839 0.09454855 0.12484747]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 160.37 mm
# Step 8:
#   Current Position: [0.08947913 0.09514964 0.12568018]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 156.82 mm
# Step 9:
#   Current Position: [0.09359674 0.09570257 0.12653966]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 152.84 mm
# Step 10:
#   Current Position: [0.09776341 0.09620541 0.12742853]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 148.81 mm
# Step 11:
#   Current Position: [0.10193016 0.09665865 0.12834558]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 144.78 mm
# Step 12:
#   Current Position: [0.10609689 0.09706324 0.12928903]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 140.74 mm
# Step 13:
#   Current Position: [0.1102636  0.09742024 0.13025719]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 136.69 mm
# Step 14:
#   Current Position: [0.11442755 0.0977299  0.13810652]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 130.16 mm
# Step 15:
#   Current Position: [0.11859377 0.09794095 0.14464329]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 124.29 mm
# Step 16:
#   Current Position: [0.12275989 0.09806522 0.14987081]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 118.96 mm
# Step 17:
#   Current Position: [0.12692614 0.09811568 0.15379679]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 114.07 mm
# Step 18:
#   Current Position: [0.13106368 0.0981052  0.15693676]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 109.46 mm
# Step 19:
#   Current Position: [0.13504316 0.09804156 0.15944918]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 105.16 mm
# Step 20:
#   Current Position: [0.13887364 0.09793254 0.16145907]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 101.14 mm
# Step 21:
#   Current Position: [0.14256313 0.09778456 0.16306695]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 97.33 mm
# Step 22:
#   Current Position: [0.14611876 0.09760304 0.16435325]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 93.72 mm
# Step 23:
#   Current Position: [0.14954625 0.09739262 0.16538249]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 90.28 mm
# Step 24:
#   Current Position: [0.15285192 0.09715702 0.16620585]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 86.99 mm
# Step 25:
#   Current Position: [0.15604098 0.09689941 0.16686463]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 83.84 mm
# Step 26:
#   Current Position: [0.15911704 0.09662158 0.16738972]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 80.83 mm
# Step 27:
#   Current Position: [0.16208734 0.09632795 0.16790526]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 77.91 mm
# Step 28:
#   Current Position: [0.16495316 0.09601901 0.16842581]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 75.09 mm
# Step 29:
#   Current Position: [0.16771698 0.09569617 0.16894996]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 72.37 mm
# Step 30:
#   Current Position: [0.17038204 0.09536035 0.16947648]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 69.74 mm
# Step 31:
#   Current Position: [0.1729511  0.09501265 0.17000416]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 67.20 mm
# Step 32:
#   Current Position: [0.17542696 0.09465414 0.17053184]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 64.74 mm
# Step 33:
#   Current Position: [0.17781234 0.09428585 0.17105846]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 62.37 mm
# Step 34:
#   Current Position: [0.18011056 0.09390869 0.17158295]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 60.08 mm
# Step 35:
#   Current Position: [0.1823236  0.09352365 0.17210448]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 57.87 mm
# Step 36:
#   Current Position: [0.1844541  0.09313161 0.1726222 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 55.74 mm
# Step 37:
#   Current Position: [0.18650463 0.09273341 0.17313537]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 53.68 mm
# Step 38:
#   Current Position: [0.18847775 0.09232985 0.17364328]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 51.70 mm
# Step 39:
#   Current Position: [0.19037564 0.09192189 0.17414519]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 49.78 mm
# Step 40:
#   Current Position: [0.19220102 0.09151004 0.17464061]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 47.94 mm
# Step 41:
#   Current Position: [0.19395629 0.09109496 0.17512898]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 46.16 mm
# Step 42:
#   Current Position: [0.19564378 0.09067733 0.17560984]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 44.44 mm
# Step 43:
#   Current Position: [0.1972658  0.09025773 0.17608277]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 42.79 mm
# Step 44:
#   Current Position: [0.19882455 0.08983674 0.17654736]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 41.20 mm
# Step 45:
#   Current Position: [0.20032224 0.08941492 0.17700331]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 39.67 mm
# Step 46:
#   Current Position: [0.20176095 0.08899277 0.1774503 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 38.19 mm
# Step 47:
#   Current Position: [0.20314278 0.08857077 0.17788807]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 36.77 mm
# Step 48:
#   Current Position: [0.20446971 0.08814938 0.17831641]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 35.40 mm
# Step 49:
#   Current Position: [0.20574373 0.08772904 0.17873514]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 34.08 mm
# Step 50:
#   Current Position: [0.2069667  0.08731013 0.17914407]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 32.82 mm
# Step 51:
#   Current Position: [0.2081405  0.08689304 0.17954312]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 31.60 mm
# Step 52:
#   Current Position: [0.20926693 0.0864781  0.17993219]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 30.42 mm
# Step 53:
#   Current Position: [0.21034771 0.08606566 0.1803112 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 29.30 mm
# Step 54:
#   Current Position: [0.21138452 0.08565602 0.1806801 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 28.21 mm
# Step 55:
#   Current Position: [0.21237901 0.08524945 0.18103886]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 27.17 mm
# Step 56:
#   Current Position: [0.21333277 0.08484622 0.18138748]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 26.17 mm
# Step 57:
#   Current Position: [0.2142479  0.08444649 0.18172598]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 25.21 mm
# Step 58:
#   Current Position: [0.21512528 0.08405057 0.1820544 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 24.28 mm
# Step 59:
#   Current Position: [0.21596639 0.08365866 0.18237281]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 23.40 mm
# Step 60:
#   Current Position: [0.21677263 0.08327095 0.18268128]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 22.55 mm
# Step 61:
#   Current Position: [0.2175448  0.08288772 0.18297988]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 21.73 mm
# Step 62:
#   Current Position: [0.21828522 0.08250893 0.18326864]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 20.95 mm
# Step 63:
#   Current Position: [0.21899468 0.08213483 0.1835477 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 20.20 mm
# Step 64:
#   Current Position: [0.2196744  0.08176554 0.18381721]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 19.48 mm
# Step 65:
#   Current Position: [0.22032496 0.08140127 0.18407726]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 18.79 mm
# Step 66:
#   Current Position: [0.22094856 0.08104195 0.18432796]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 18.13 mm
# Step 67:
#   Current Position: [0.22154582 0.08068775 0.18456946]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 17.50 mm
# Step 68:
#   Current Position: [0.22211775 0.08033877 0.18480192]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 16.90 mm
# Step 69:
#   Current Position: [0.22266541 0.07999507 0.1850255 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 16.33 mm
# Step 70:
#   Current Position: [0.22318977 0.07965671 0.18524034]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 15.78 mm
# Step 71:
#   Current Position: [0.22369175 0.07932375 0.18544662]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 15.25 mm
# Step 72:
#   Current Position: [0.22417226 0.07899623 0.18564448]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 14.75 mm
# Step 73:
#   Current Position: [0.22463219 0.07867417 0.18583411]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 14.27 mm
# Step 74:
#   Current Position: [0.22507238 0.07835762 0.18601568]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 13.82 mm
# Step 75:
#   Current Position: [0.22549365 0.07804658 0.18618935]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 13.38 mm
# Step 76:
#   Current Position: [0.22589676 0.07774106 0.18635531]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 12.97 mm
# Step 77:
#   Current Position: [0.22628249 0.07744107 0.18651372]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 12.58 mm
# Step 78:
#   Current Position: [0.22665103 0.07714671 0.1866648 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 12.20 mm
# Step 79:
#   Current Position: [0.22700356 0.07685786 0.18680866]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 11.85 mm
# Step 80:
#   Current Position: [0.2273408  0.0765745  0.18694548]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 11.51 mm
# Step 81:
#   Current Position: [0.22766341 0.07629665 0.18707547]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 11.19 mm
# Step 82:
#   Current Position: [0.22797239 0.07602418 0.18719882]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 10.89 mm
# Step 83:
#   Current Position: [0.22826757 0.07575723 0.18731572]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 10.61 mm
# Step 84:
#   Current Position: [0.22855029 0.07549559 0.18742636]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 10.33 mm
# Step 85:
#   Current Position: [0.22882034 0.07523941 0.18753089]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 10.08 mm
# Step 86:
#   Current Position: [0.22907862 0.07498856 0.18762949]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 9.84 mm
# Step 87:
#   Current Position: [0.22932604 0.0747429  0.18772237]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 9.61 mm
# Step 88:
#   Current Position: [0.22956231 0.07450256 0.18780966]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 9.39 mm
# Step 89:
#   Current Position: [0.22978868 0.07426732 0.18789157]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 9.19 mm
# Step 90:
#   Current Position: [0.2300048  0.07403731 0.18796825]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 9.00 mm
# Step 91:
#   Current Position: [0.23021153 0.07381237 0.18803987]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 8.82 mm
# Step 92:
#   Current Position: [0.23040962 0.07359235 0.1881066 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 8.65 mm
# Step 93:
#   Current Position: [0.23059875 0.07337739 0.18816859]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 8.49 mm
# Step 94:
#   Current Position: [0.23077963 0.07316732 0.188226  ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 8.34 mm
# Step 95:
#   Current Position: [0.23095304 0.072962   0.18827902]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 8.19 mm
# Step 96:
#   Current Position: [0.23111857 0.07276154 0.18832776]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 8.06 mm
# Step 97:
#   Current Position: [0.23127693 0.07256579 0.1883724 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 7.94 mm
# Step 98:
#   Current Position: [0.2314288  0.07237457 0.1884131 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 7.82 mm
# Step 99:
#   Current Position: [0.23157378 0.07218801 0.18844998]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 7.71 mm
# Step 100:
#   Current Position: [0.23171249 0.07200596 0.1884832 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 7.61 mm
# Step 101:
#   Current Position: [0.2318456  0.07182822 0.18851289]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 7.51 mm
# Step 102:
#   Current Position: [0.23197266 0.07165496 0.18853919]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 7.42 mm
# Step 103:
#   Current Position: [0.23209427 0.07148597 0.18856223]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 7.33 mm
# Step 104:
#   Current Position: [0.23221105 0.07132109 0.18858217]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 7.25 mm
# Step 105:
#   Current Position: [0.23232254 0.07116046 0.1885991 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 7.17 mm
# Step 106:
#   Current Position: [0.2324293  0.07100389 0.18861315]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 7.10 mm
# Step 107:
#   Current Position: [0.23253155 0.07085131 0.18862446]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 7.03 mm
# Step 108:
#   Current Position: [0.23262984 0.07070255 0.18863314]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 6.97 mm
# Step 109:
#   Current Position: [0.23272368 0.07055775 0.18863931]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 6.91 mm
# Step 110:
#   Current Position: [0.23281361 0.07041672 0.18864308]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 6.85 mm
# Step 111:
#   Current Position: [0.23289981 0.0702794  0.18864456]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 6.80 mm
# Step 112:
#   Current Position: [0.23298281 0.07014558 0.18864387]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 6.74 mm
# Step 113:
#   Current Position: [0.23306206 0.07001545 0.1886411 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 6.69 mm
# Step 114:
#   Current Position: [0.23313808 0.06988881 0.18863633]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 6.65 mm
# Step 115:
#   Current Position: [0.23321103 0.06976558 0.1886297 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 6.60 mm
# Step 116:
#   Current Position: [0.23328136 0.06964557 0.1886213 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 6.56 mm
# Step 117:
#   Current Position: [0.23334856 0.06952897 0.18861118]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 6.52 mm
# Step 118:
#   Current Position: [0.23341309 0.06941556 0.18859947]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 6.48 mm
# Step 119:
#   Current Position: [0.23347506 0.06930529 0.18858624]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 6.44 mm
# Step 120:
#   Current Position: [0.23353462 0.06919809 0.18857156]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 6.41 mm
# Step 121:
#   Current Position: [0.23359221 0.06909377 0.18855557]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 6.37 mm
# Step 122:
#   Current Position: [0.23364726 0.06899251 0.18853828]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 6.34 mm
# Step 123:
#   Current Position: [0.23370022 0.06889412 0.1885198 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 6.31 mm
# Step 124:
#   Current Position: [0.23375116 0.06879853 0.1885002 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 6.28 mm
# Step 125:
#   Current Position: [0.2338002  0.06870567 0.18847954]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 6.25 mm
# Step 126:
#   Current Position: [0.23384742 0.0686155  0.18845789]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 6.22 mm
# Step 127:
#   Current Position: [0.23389328 0.0685278  0.18843536]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 6.19 mm
# Step 128:
#   Current Position: [0.23393713 0.06844278 0.18841195]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 6.16 mm
# Step 129:
#   Current Position: [0.23397942 0.06836026 0.18838777]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 6.14 mm
# Step 130:
#   Current Position: [0.2340202  0.06828016 0.18836282]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 6.11 mm
# Step 131:
#   Current Position: [0.23405956 0.06820244 0.18833722]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 6.08 mm
# Step 132:
#   Current Position: [0.23409757 0.06812702 0.188311  ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 6.06 mm
# Step 133:
#   Current Position: [0.23413461 0.06805372 0.18828422]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 6.03 mm
# Step 134:
#   Current Position: [0.2341701  0.06798276 0.18825692]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 6.01 mm
# Step 135:
#   Current Position: [0.2342044  0.06791395 0.18822914]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.99 mm
# Step 136:
#   Current Position: [0.23423757 0.06784722 0.18820095]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.96 mm
# Step 137:
#   Current Position: [0.23426968 0.06778253 0.18817237]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.94 mm
# Step 138:
#   Current Position: [0.23430076 0.06771982 0.18814346]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.92 mm
# Step 139:
#   Current Position: [0.23433088 0.06765904 0.18811426]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.90 mm
# Step 140:
#   Current Position: [0.23436005 0.06760013 0.1880848 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.87 mm
# Step 141:
#   Current Position: [0.2343887  0.06754292 0.18805516]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.85 mm
# Step 142:
#   Current Position: [0.23441616 0.06748764 0.18802531]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.83 mm
# Step 143:
#   Current Position: [0.2344428  0.06743409 0.18799531]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.81 mm
# Step 144:
#   Current Position: [0.23446867 0.06738223 0.18796521]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.79 mm
# Step 145:
#   Current Position: [0.2344938  0.06733201 0.18793502]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.77 mm
# Step 146:
#   Current Position: [0.23451824 0.06728339 0.18790479]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.75 mm
# Step 147:
#   Current Position: [0.23454201 0.06723633 0.18787453]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.73 mm
# Step 148:
#   Current Position: [0.23456512 0.06719077 0.18784426]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.71 mm
# Step 149:
#   Current Position: [0.23458762 0.06714668 0.18781404]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.69 mm
# Step 150:
#   Current Position: [0.23460954 0.06710402 0.18778387]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.68 mm
# Step 151:
#   Current Position: [0.23463124 0.06706259 0.1877538 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.66 mm
# Step 152:
#   Current Position: [0.23465206 0.06702268 0.18772382]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.64 mm
# Step 153:
#   Current Position: [0.23467235 0.06698407 0.18769394]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.62 mm
# Step 154:
#   Current Position: [0.23469214 0.06694673 0.18766421]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.60 mm
# Step 155:
#   Current Position: [0.23471147 0.06691062 0.18763463]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.59 mm
# Step 156:
#   Current Position: [0.23473033 0.06687572 0.18760523]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.57 mm
# Step 157:
#   Current Position: [0.23474877 0.06684198 0.18757603]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.55 mm
# Step 158:
#   Current Position: [0.23476677 0.06680937 0.18754701]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.54 mm
# Step 159:
#   Current Position: [0.23478438 0.06677786 0.18751822]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.52 mm
# Step 160:
#   Current Position: [0.23480159 0.06674741 0.18748969]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.50 mm
# Step 161:
#   Current Position: [0.23481843 0.066718   0.18746138]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.49 mm
# Step 162:
#   Current Position: [0.23483491 0.06668959 0.18743333]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.47 mm
# Step 163:
#   Current Position: [0.23485103 0.06666215 0.18740556]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.46 mm
# Step 164:
#   Current Position: [0.23486684 0.06663565 0.18737806]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.44 mm
# Step 165:
#   Current Position: [0.23488231 0.06661006 0.18735087]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.43 mm
# Step 166:
#   Current Position: [0.23489782 0.06658521 0.18732399]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.41 mm
# Step 167:
#   Current Position: [0.23491268 0.06656137 0.1872974 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.40 mm
# Step 168:
#   Current Position: [0.23492725 0.06653837 0.18727112]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.38 mm
# Step 169:
#   Current Position: [0.23494154 0.06651617 0.18724516]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.37 mm
# Step 170:
#   Current Position: [0.23495556 0.06649476 0.18721952]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.36 mm
# Step 171:
#   Current Position: [0.2349693  0.06647409 0.18719421]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.34 mm
# Step 172:
#   Current Position: [0.2349828  0.06645416 0.18716924]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.33 mm
# Step 173:
#   Current Position: [0.23499604 0.06643494 0.1871446 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.32 mm
# Step 174:
#   Current Position: [0.23500903 0.06641641 0.18712032]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.30 mm
# Step 175:
#   Current Position: [0.2350218  0.06639854 0.18709637]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.29 mm
# Step 176:
#   Current Position: [0.23503433 0.06638131 0.18707277]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.28 mm
# Step 177:
#   Current Position: [0.23504664 0.06636471 0.18704952]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.27 mm
# Step 178:
#   Current Position: [0.23505872 0.06634872 0.18702663]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.26 mm
# Step 179:
#   Current Position: [0.23507062 0.06633329 0.18700409]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.24 mm
# Step 180:
#   Current Position: [0.2350823  0.06631844 0.18698192]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.23 mm
# Step 181:
#   Current Position: [0.23509377 0.06630414 0.18696009]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.22 mm
# Step 182:
#   Current Position: [0.23510505 0.06629036 0.18693863]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.21 mm
# Step 183:
#   Current Position: [0.23511614 0.06627709 0.18691751]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.20 mm
# Step 184:
#   Current Position: [0.23512703 0.06626431 0.18689676]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.19 mm
# Step 185:
#   Current Position: [0.23513776 0.06625201 0.18687636]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.18 mm
# Step 186:
#   Current Position: [0.2351483  0.06624017 0.18685631]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.17 mm
# Step 187:
#   Current Position: [0.23515865 0.06622877 0.18683663]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.16 mm
# Step 188:
#   Current Position: [0.23516884 0.0662178  0.18681729]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.15 mm
# Step 189:
#   Current Position: [0.23517887 0.06620725 0.1867983 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.14 mm
# Step 190:
#   Current Position: [0.23518872 0.0661971  0.18677968]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.13 mm
# Step 191:
#   Current Position: [0.23519842 0.06618734 0.18676138]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.12 mm
# Step 192:
#   Current Position: [0.23520796 0.06617795 0.18674344]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.12 mm
# Step 193:
#   Current Position: [0.23521733 0.06616892 0.18672584]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.11 mm
# Step 194:
#   Current Position: [0.23522656 0.06616024 0.18670857]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.10 mm
# Step 195:
#   Current Position: [0.23523563 0.06615189 0.18669164]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.09 mm
# Step 196:
#   Current Position: [0.23524454 0.06614387 0.18667504]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.08 mm
# Step 197:
#   Current Position: [0.23525332 0.06613617 0.18665878]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.07 mm
# Step 198:
#   Current Position: [0.23526196 0.06612876 0.18664286]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.07 mm
# Step 199:
#   Current Position: [0.23527044 0.06612165 0.18662724]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.06 mm
# Step 200:
#   Current Position: [0.2352788  0.06611481 0.18661194]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.05 mm
# Step 201:
#   Current Position: [0.23528701 0.06610824 0.18659696]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.05 mm
# Step 202:
#   Current Position: [0.23529509 0.06610194 0.1865823 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.04 mm
# Step 203:
#   Current Position: [0.23530301 0.06609589 0.18656795]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.03 mm
# Step 204:
#   Current Position: [0.23531084 0.06609008 0.1865539 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.03 mm
# Step 205:
#   Current Position: [0.23531851 0.0660845  0.18654014]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.02 mm
# Step 206:
#   Current Position: [0.23532607 0.06607915 0.1865267 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.01 mm
# Step 207:
#   Current Position: [0.23533349 0.06607401 0.18651353]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.01 mm
# Step 208:
#   Current Position: [0.23534079 0.06606908 0.18650067]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.00 mm
# Step 209:
#   Current Position: [0.23534796 0.06606436 0.18648808]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 5.00 mm
# Step 210:
#   Current Position: [0.23535502 0.06605982 0.18647577]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.99 mm
# Step 211:
#   Current Position: [0.23536195 0.06605548 0.18646374]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.98 mm
# Step 212:
#   Current Position: [0.23536877 0.06605131 0.18645199]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.98 mm
# Step 213:
#   Current Position: [0.23537546 0.06604731 0.1864405 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.97 mm
# Step 214:
#   Current Position: [0.23538205 0.06604348 0.18642928]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.97 mm
# Step 215:
#   Current Position: [0.23538853 0.06603982 0.18641831]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.96 mm
# Step 216:
#   Current Position: [0.23539488 0.0660363  0.1864076 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.96 mm
# Step 217:
#   Current Position: [0.23540114 0.06603293 0.18639714]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.96 mm
# Step 218:
#   Current Position: [0.23540728 0.06602971 0.18638693]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.95 mm
# Step 219:
#   Current Position: [0.2354133  0.06602661 0.18637696]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.95 mm
# Step 220:
#   Current Position: [0.23541923 0.06602365 0.18636723]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.94 mm
# Step 221:
#   Current Position: [0.23542504 0.06602082 0.18635772]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.94 mm
# Step 222:
#   Current Position: [0.23543076 0.0660181  0.18634845]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.94 mm
# Step 223:
#   Current Position: [0.23543638 0.06601551 0.18633941]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.93 mm
# Step 224:
#   Current Position: [0.23544188 0.06601302 0.18633059]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.93 mm
# Step 225:
#   Current Position: [0.2354473  0.06601065 0.18632197]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.92 mm
# Step 226:
#   Current Position: [0.2354526  0.06600837 0.18631358]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.92 mm
# Step 227:
#   Current Position: [0.23545782 0.0660062  0.18630539]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.92 mm
# Step 228:
#   Current Position: [0.23546295 0.06600412 0.1862974 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.91 mm
# Step 229:
#   Current Position: [0.23546797 0.06600213 0.18628962]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.91 mm
# Step 230:
#   Current Position: [0.23547292 0.06600023 0.18628204]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.91 mm
# Step 231:
#   Current Position: [0.23547776 0.06599841 0.18627465]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.90 mm
# Step 232:
#   Current Position: [0.2354825  0.06599668 0.18626744]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.90 mm
# Step 233:
#   Current Position: [0.23548716 0.06599502 0.18626042]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.90 mm
# Step 234:
#   Current Position: [0.23549174 0.06599343 0.18625358]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.90 mm
# Step 235:
#   Current Position: [0.23549622 0.06599192 0.18624692]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.89 mm
# Step 236:
#   Current Position: [0.23550063 0.06599046 0.18624043]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.89 mm
# Step 237:
#   Current Position: [0.23550494 0.06598908 0.18623412]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.89 mm
# Step 238:
#   Current Position: [0.23550917 0.06598777 0.18622796]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.89 mm
# Step 239:
#   Current Position: [0.23551333 0.06598651 0.18622197]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.88 mm
# Step 240:
#   Current Position: [0.2355174  0.06598531 0.18621613]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.88 mm
# Step 241:
#   Current Position: [0.23552139 0.06598416 0.18621045]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.88 mm
# Step 242:
#   Current Position: [0.2355253  0.06598306 0.18620493]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.88 mm
# Step 243:
#   Current Position: [0.23552912 0.06598202 0.18619955]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.88 mm
# Step 244:
#   Current Position: [0.2355329  0.06598102 0.18619432]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.87 mm
# Step 245:
#   Current Position: [0.23553658 0.06598007 0.18618923]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.87 mm
# Step 246:
#   Current Position: [0.23554018 0.06597917 0.18618427]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.87 mm
# Step 247:
#   Current Position: [0.23554371 0.0659783  0.18617946]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.87 mm
# Step 248:
#   Current Position: [0.23554718 0.06597748 0.18617477]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.87 mm
# Step 249:
#   Current Position: [0.23555057 0.06597669 0.1861702 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.87 mm
# Step 250:
#   Current Position: [0.2355539  0.06597594 0.18616578]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.86 mm
# Step 251:
#   Current Position: [0.23555715 0.06597523 0.18616147]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.86 mm
# Step 252:
#   Current Position: [0.23556034 0.06597456 0.18615729]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.86 mm
# Step 253:
#   Current Position: [0.23556347 0.06597391 0.18615322]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.86 mm
# Step 254:
#   Current Position: [0.23556653 0.06597329 0.18614925]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.86 mm
# Step 255:
#   Current Position: [0.23556952 0.0659727  0.18614541]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.86 mm
# Step 256:
#   Current Position: [0.23557244 0.06597214 0.18614167]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.86 mm
# Step 257:
#   Current Position: [0.23557532 0.06597161 0.18613803]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.85 mm
# Step 258:
#   Current Position: [0.23557812 0.06597111 0.1861345 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.85 mm
# Step 259:
#   Current Position: [0.23558086 0.06597062 0.18613108]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.85 mm
# Step 260:
#   Current Position: [0.23558356 0.06597016 0.18612775]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.85 mm
# Step 261:
#   Current Position: [0.23558618 0.06596973 0.18612452]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.85 mm
# Step 262:
#   Current Position: [0.23558876 0.06596931 0.18612137]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.85 mm
# Step 263:
#   Current Position: [0.23559128 0.06596892 0.18611832]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.85 mm
# Step 264:
#   Current Position: [0.23559374 0.06596854 0.18611537]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.85 mm
# Step 265:
#   Current Position: [0.23559615 0.06596818 0.1861125 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.85 mm
# Step 266:
#   Current Position: [0.2355985  0.06596784 0.18610969]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.85 mm
# Step 267:
#   Current Position: [0.23560081 0.06596752 0.186107  ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.85 mm
# Step 268:
#   Current Position: [0.23560306 0.0659672  0.18610436]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.84 mm
# Step 269:
#   Current Position: [0.23560527 0.06596691 0.18610181]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.84 mm
# Step 270:
#   Current Position: [0.23560742 0.06596663 0.18609934]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.84 mm
# Step 271:
#   Current Position: [0.23560953 0.06596637 0.18609692]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.84 mm
# Step 272:
#   Current Position: [0.23561159 0.06596611 0.1860946 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.84 mm
# Step 273:
#   Current Position: [0.2356136  0.06596588 0.18609233]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.84 mm
# Step 274:
#   Current Position: [0.23561557 0.06596565 0.18609014]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.84 mm
# Step 275:
#   Current Position: [0.23561749 0.06596543 0.18608801]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.84 mm
# Step 276:
#   Current Position: [0.23561935 0.06596522 0.18608595]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.84 mm
# Step 277:
#   Current Position: [0.2356212  0.06596502 0.18608394]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.84 mm
# Step 278:
#   Current Position: [0.23562299 0.06596483 0.186082  ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.84 mm
# Step 279:
#   Current Position: [0.23562473 0.06596465 0.18608013]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.84 mm
# Step 280:
#   Current Position: [0.23562644 0.06596449 0.1860783 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.84 mm
# Step 281:
#   Current Position: [0.23562811 0.06596433 0.18607652]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.84 mm
# Step 282:
#   Current Position: [0.23562974 0.06596417 0.18607481]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.84 mm
# Step 283:
#   Current Position: [0.23563133 0.06596403 0.18607315]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.84 mm
# Step 284:
#   Current Position: [0.23563288 0.06596389 0.18607154]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.84 mm
# Step 285:
#   Current Position: [0.2356344  0.06596375 0.18606998]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.84 mm
# Step 286:
#   Current Position: [0.23563589 0.06596363 0.18606846]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 287:
#   Current Position: [0.23563734 0.06596351 0.186067  ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 288:
#   Current Position: [0.23563874 0.06596339 0.18606558]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 289:
#   Current Position: [0.23564012 0.06596328 0.1860642 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 290:
#   Current Position: [0.23564146 0.06596318 0.18606287]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 291:
#   Current Position: [0.23564278 0.06596307 0.18606158]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 292:
#   Current Position: [0.23564406 0.06596299 0.18606032]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 293:
#   Current Position: [0.2356453  0.06596289 0.18605912]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 294:
#   Current Position: [0.23564652 0.06596281 0.18605794]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 295:
#   Current Position: [0.23564771 0.06596272 0.18605681]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 296:
#   Current Position: [0.23564887 0.06596264 0.1860557 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 297:
#   Current Position: [0.23565    0.06596257 0.18605465]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 298:
#   Current Position: [0.2356511  0.06596249 0.18605362]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 299:
#   Current Position: [0.23565218 0.06596243 0.18605262]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 300:
#   Current Position: [0.23565322 0.06596236 0.18605165]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 301:
#   Current Position: [0.23565425 0.06596229 0.18605071]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 302:
#   Current Position: [0.23565525 0.06596223 0.18604982]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 303:
#   Current Position: [0.23565622 0.06596217 0.18604894]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 304:
#   Current Position: [0.23565716 0.06596211 0.18604809]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 305:
#   Current Position: [0.23565808 0.06596206 0.18604727]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 306:
#   Current Position: [0.23565899 0.06596201 0.18604648]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 307:
#   Current Position: [0.23565985 0.06596196 0.1860457 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 308:
#   Current Position: [0.23566072 0.0659619  0.18604496]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 309:
#   Current Position: [0.23566155 0.06596186 0.18604425]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 310:
#   Current Position: [0.23566236 0.06596182 0.18604355]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 311:
#   Current Position: [0.23566315 0.06596177 0.18604288]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 312:
#   Current Position: [0.23566392 0.06596173 0.18604223]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 313:
#   Current Position: [0.23566467 0.06596169 0.1860416 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 314:
#   Current Position: [0.2356654  0.06596165 0.186041  ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 315:
#   Current Position: [0.23566611 0.06596161 0.1860404 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 316:
#   Current Position: [0.2356668  0.06596157 0.18603984]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 317:
#   Current Position: [0.23566748 0.06596153 0.18603928]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 318:
#   Current Position: [0.23566814 0.0659615  0.18603875]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 319:
#   Current Position: [0.23566878 0.06596147 0.18603824]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 320:
#   Current Position: [0.2356694  0.06596144 0.18603775]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 321:
#   Current Position: [0.23567    0.0659614  0.18603726]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 322:
#   Current Position: [0.2356706  0.06596137 0.1860368 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 323:
#   Current Position: [0.23567118 0.06596134 0.18603635]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 324:
#   Current Position: [0.23567173 0.06596131 0.18603592]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 325:
#   Current Position: [0.23567228 0.06596128 0.1860355 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 326:
#   Current Position: [0.2356728  0.06596125 0.1860351 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 327:
#   Current Position: [0.23567332 0.06596122 0.1860347 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 328:
#   Current Position: [0.23567382 0.06596119 0.18603432]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 329:
#   Current Position: [0.2356743  0.06596117 0.18603396]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 330:
#   Current Position: [0.23567478 0.06596114 0.1860336 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 331:
#   Current Position: [0.23567525 0.06596111 0.18603326]
# ...
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 543:
#   Current Position: [0.23569089 0.06595947 0.18602352]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 544:
#   Current Position: [0.23569089 0.06595947 0.18602352]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 545:
#   Current Position: [0.23569089 0.06595947 0.18602352]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 546:
#   Current Position: [0.23569089 0.06595946 0.18602352]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 547:
#   Current Position: [0.23569089 0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 548:
#   Current Position: [0.23569089 0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 549:
#   Current Position: [0.23569089 0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 550:
#   Current Position: [0.23569089 0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 551:
#   Current Position: [0.23569089 0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 552:
#   Current Position: [0.23569089 0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 553:
#   Current Position: [0.23569089 0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 554:
#   Current Position: [0.23569089 0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 555:
#   Current Position: [0.23569089 0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 556:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 557:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 558:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 559:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 560:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 561:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 562:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 563:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 564:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 565:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 566:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 567:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 568:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 569:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 570:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 571:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 572:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 573:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 574:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 575:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 576:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 577:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 578:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 579:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 580:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 581:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 582:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 583:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 584:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 585:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 586:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 587:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 588:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 589:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 590:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 591:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 592:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 593:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 594:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 595:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 596:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 597:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 598:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 599:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 600:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 601:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 602:
#   Current Position: [0.2356909  0.06595945 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 603:
#   Current Position: [0.2356909  0.06595946 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 604:
#   Current Position: [0.2356909  0.06595945 0.1860235 ]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 605:
#   Current Position: [0.2356909  0.06595946 0.18602349]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 606:
#   Current Position: [0.2356909  0.06595945 0.18602349]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 607:
#   Current Position: [0.2356909  0.06595946 0.18602349]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 608:
#   Current Position: [0.2356909  0.06595945 0.18602349]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 609:
#   Current Position: [0.2356909  0.06595946 0.18602349]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 610:
#   Current Position: [0.2356909  0.06595945 0.18602349]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 611:
#   Current Position: [0.2356909  0.06595946 0.18602349]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 612:
#   Current Position: [0.23569092 0.06595945 0.18602349]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 613:
#   Current Position: [0.2356909  0.06595945 0.18602349]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 614:
#   Current Position: [0.2356909  0.06595946 0.18602349]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 615:
#   Current Position: [0.23569092 0.06595945 0.18602349]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 616:
#   Current Position: [0.2356909  0.06595945 0.18602349]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 617:
#   Current Position: [0.23569092 0.06595945 0.18602349]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 618:
#   Current Position: [0.2356909  0.06595945 0.18602349]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 619:
#   Current Position: [0.2356909  0.06595945 0.18602349]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 620:
#   Current Position: [0.23569092 0.06595946 0.18602349]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 621:
#   Current Position: [0.2356909  0.06595945 0.18602349]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 622:
#   Current Position: [0.23569092 0.06595946 0.18602349]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 623:
#   Current Position: [0.2356909  0.06595945 0.18602349]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 624:
#   Current Position: [0.23569092 0.06595945 0.18602349]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 625:
#   Current Position: [0.2356909  0.06595945 0.18602349]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 626:
#   Current Position: [0.23569092 0.06595946 0.18602349]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 627:
#   Current Position: [0.2356909  0.06595945 0.18602349]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 628:
#   Current Position: [0.23569092 0.06595945 0.18602349]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 629:
#   Current Position: [0.2356909  0.06595945 0.18602349]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 630:
#   Current Position: [0.2356909  0.06595945 0.18602349]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 631:
#   Current Position: [0.23569092 0.06595946 0.18602349]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 632:
#   Current Position: [0.2356909  0.06595945 0.18602349]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 633:
#   Current Position: [0.23569092 0.06595946 0.18602349]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 634:
#   Current Position: [0.2356909  0.06595945 0.18602349]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 635:
#   Current Position: [0.23569092 0.06595946 0.18602349]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 636:
#   Current Position: [0.2356909  0.06595945 0.18602349]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 637:
#   Current Position: [0.23569092 0.06595945 0.18602349]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 638:
#   Current Position: [0.2356909  0.06595945 0.18602349]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 639:
#   Current Position: [0.2356909  0.06595945 0.18602349]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# Step 640:
#   Current Position: [0.23569092 0.06595946 0.18602349]
#   Goal Position: [0.23310898 0.06773573 0.18234673]
#   Distance to Goal: 4.83 mm
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[3], line 59
#      57 # Run the test
#      58 if __name__ == "__main__":
# ---> 59     test_model(env, model, max_steps=10000)
#
# Cell In[3], line 35, in test_model(env, model, max_steps)
#      32 for step in range(max_steps):
#      33     # Predict the action for the current state
#      34     action, _ = model.predict(obs, deterministic=True)  # Use deterministic=True for testing
# ---> 35     obs, _, terminated, truncated, _ = env.step(action)  # Execute the action
#      37     # Calculate the accuracy (distance to the goal) in mm
#      38     current_position = obs[:3]  # Extract the current position from the observation
#
# Cell In[1], line 63, in OT2Env.step(self, action)
#      61 action = np.append(np.array(action, dtype=np.float32), 0)
#      62 # Call the step function
# ---> 63 observation = self.sim.run([action])
#      64 pipette_position = self.sim.get_pipette_position(self.sim.robotIds[0])
#      65 # Process observation
#
# File c:\Users\jarro\Documents\GitHub\Reinforcement learning\sim_class.py:253, in Simulation.run(self, actions, num_steps)
#     250     if self.render:
#     251         time.sleep(1./240.) # slow down the simulation
# --> 253 return self.get_states()
#
# File c:\Users\jarro\Documents\GitHub\Reinforcement learning\sim_class.py:304, in Simulation.get_states(self)
#     302 states = {}
#     303 for robotId in self.robotIds:
# --> 304     raw_joint_states = p.getJointStates(robotId, [0, 1, 2])
#     306     # Convert joint states into a dictionary
#     307     joint_states = {}
#
# error: Not connected to physics server.
